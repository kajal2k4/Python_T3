# %%
import requests
from bs4 import BeautifulSoup

# %%
website = 'https://subslikescript.com/movie/Titanic-120338'
result = requests.get(website).text
soup = BeautifulSoup(result,'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html dir="ltr" lang="en">
# <head>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-120598793-1"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-120598793-1');
# </script>
# <meta charset="utf-8"/>
# <title>    Titanic (1997) Movie Script
#  | Subs like Script</title>
# <meta "="" content="    Read " created="" from="" movie="" name="description" script,="" srt="" subtitles="" titanic"=""/>
# <meta content="    transcript, movie, subtitles, scripts, film, video, media, subs, srt
# " name="keywords"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="index, follow" name="robots"/>
# <link href="/favicon.ico" rel="shortcut icon"/>
# <meta content="ZSV8vZBJknXNGsvcTyHVchysb8gLZm9DLkk7zelD" name="csrf-token"/>
# ...

# %%
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <html dir="ltr" lang="en">
# <head>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-120598793-1"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-120598793-1');
# </script>
# <meta charset="utf-8"/>
# <title>    Titanic (1997) Movie Script
#  | Subs like Script</title>
# <meta "="" content="    Read " created="" from="" movie="" name="description" script,="" srt="" subtitles="" titanic"=""/>
# <meta content="    transcript, movie, subtitles, scripts, film, video, media, subs, srt
# " name="keywords"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="index, follow" name="robots"/>
# <link href="/favicon.ico" rel="shortcut icon"/>
# ...

# %%
print(soup.find('article',class_='main-article'))
# Out:
# <article class="main-article">
# <h1>Titanic (1997) - full transcript</h1>
# <p class="plot">A seventeen-year-old aristocrat falls in love with a kind but poor artist aboard the luxurious, ill-fated R.M.S. Titanic.</p>
# <script async="" crossorigin="anonymous" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-9736463211397065"></script>
# <!-- content_before_content_square_adaptive -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-9736463211397065" data-ad-format="auto" data-ad-slot="9732296380" data-full-width-responsive="true" style="display:block"></ins>
# <script>
#     (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# <div class="full-script" data-imdb-id="120338" id="cue-app">
# <div class="subtitle-cue">
# <p class="cue-line" data-cue-idx="0" data-line-idx="0">13 meters. You should see it.</p>
# </div>
# <div class="subtitle-cue">
# ...

# %%
print(soup.find('h1').get_text())
# Out:
# Titanic (1997) - full transcript

# %%
print(soup.find('title').get_text())
# Out:
#     Titanic (1997) Movie Script
#  | Subs like Script

# %%
title_text=soup.find('div',class_='full-script')
title_text
# Out:
# <div class="full-script" data-imdb-id="120338" id="cue-app">
# <div class="subtitle-cue">
# <p class="cue-line" data-cue-idx="0" data-line-idx="0">13 meters. You should see it.</p>
# </div>
# <div class="subtitle-cue">
# <p class="cue-line" data-cue-idx="1" data-line-idx="0">Okay, take her up and over the bow rail.</p>
# </div>
# <div class="subtitle-cue">
# <p class="cue-line" data-cue-idx="2" data-line-idx="0">Mir 2, we're going over the bow.</p>
# <p class="cue-line" data-cue-idx="2" data-line-idx="1">Stay with us.</p>
# </div>
# <div class="subtitle-cue">
# <p class="cue-line" data-cue-idx="3" data-line-idx="0">Okay, quiet. We're rolling.</p>
# </div>
# <div class="subtitle-cue">
# <p class="cue-line" data-cue-idx="4" data-line-idx="0">Seeing her coming out of the</p>
# <p class="cue-line" data-cue-idx="4" data-line-idx="1">darkness like a ghost ship...</p>
# </div>
# <div class="subtitle-cue">
# ...

# %%
web = 'https://subslikescript.com/movies'
result = requests.get(web).text
soup = BeautifulSoup(result)
soup
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
# <head>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-120598793-1"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-120598793-1');
# </script>
# <meta charset="utf-8"/>
# <title>All English transcripts for movies  | Subs like Script</title>
# <meta content="List of movie scripts " name="description"/>
# <meta content="transcript, movie, subtitles, scripts, film, video, media, subs, srt " name="keywords"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="index, follow" name="robots"/>
# <link href="/favicon.ico" rel="shortcut icon"/>
# <meta content="A1EzJX19cXeGlJIUnpgmi09V0LIiXMHP5kJIN7Fw" name="csrf-token"/>
# ...

# %%
box = soup.find('article',class_='main-article')
soup.find_all('a',href=True)
# Out:
# [<a href="/" title="Subs like Script - all Movies and TV Shows Transcripts">
#  <span>SUBSLIKESCRIPT</span>
#  </a>,
#  <a href="/movies" target="_self" title="All movies transcripts">Movies</a>,
#  <a href="/series" target="_self" title="All Tv Shows transcripts">TV Shows</a>,
#  <a href="/">Home</a>,
#  <a href="/movies_letter-sign" title="Movies whose names start with a sign or a digit">[sign or digit]</a>,
#  <a href="/movies_letter-A" title='Movies transcripts starting with letter "A"'>A</a>,
#  <a href="/movies_letter-B" title='Movies transcripts starting with letter "B"'>B</a>,
#  <a href="/movies_letter-C" title='Movies transcripts starting with letter "C"'>C</a>,
#  <a href="/movies_letter-D" title='Movies transcripts starting with letter "D"'>D</a>,
#  <a href="/movies_letter-E" title='Movies transcripts starting with letter "E"'>E</a>,
#  <a href="/movies_letter-F" title='Movies transcripts starting with letter "F"'>F</a>,
# ...

# %%
links=[]
for link in box.findAll("a",href=True):
    links.append(link["href"])
links
# Out:
# ['/movie/Gereza-22857380',
#  '/movie/Dragon_Hunter-22008250',
#  '/movie/House_of_Inequity-5598934',
#  '/movie/Jackpot_Island_Kumanthong_Returns-25260658',
#  '/movie/Match-13490000',
#  '/movie/Snow_White_and_the_Fairytale_Fun_Force-22700808',
#  '/movie/The_Love_Club-19896920',
#  '/movie/Haunted_Hotties-24018636',
#  '/movie/One_Year_Off-14130940',
#  '/movie/Sweeter_Than_Chocolate-25391002',
#  '/movie/Disquiet-25869142',
#  '/movie/Among_the_Beasts-26343318',
#  '/movie/Taming_Speed-25969676',
#  '/movie/Randy_Feltface_The_Last_Temptation_of_Randy-17527566',
#  '/movie/Alemanji-23666980',
#  '/movie/Darkheart_Manor-12569866',
#  '/movie/Innocent_Vengeance-26505553',
#  '/movie/Ho_Ja_Mukt-25150506',
#  '/movie/Boy_from_Nowhere-26713915',
#  '/movie/Rent-a-Groom-15352290',
#  '/movie/Unlocked-26160190',
#  '/movie/j-hope_IN_THE_BOX-26425683',
#  '/movie/Suki-26734145',
#  '/movie/Re-Resonator_Looking_Back_at_from_Beyond-26625455',
# ...

# %%
List = []
for i in links:
    try:
        url = f"https://subslikescript.com{i}"
        res = requests.get(url).text
        soup = BeautifulSoup(res,'html.parser')
        box = soup.find('article',class_='main-article')
        title = box.find('h1').text
        List.append(title)
        script = box.find('div',class_='full-script').text
        with open(f"{title}.txt",'w',encoding='utf-8') as file:
            file.write(script)
    except Exception as e:
        print(e)
# Out:
# [Errno 22] Invalid argument: "Why Can't My Life Be a Rom Com? (2023) - full transcript.txt"
